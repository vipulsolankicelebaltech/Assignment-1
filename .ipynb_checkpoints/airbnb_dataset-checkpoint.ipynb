# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('imports-85.csv')
data.shape
# Out:
# (205, 26)

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# # Handling Missing values

# %%
# Checking for the percentage of ? values in each features before handling them
for i in data.columns:
    if data[data[i]=='?'].shape[0] > 0:
        print(i,data[i][data[i]=='?'].value_counts(),data[i][data[i]=='?'].value_counts()/data.shape[0])
#         data[i]=data[i].replace('?',np.mean(temp),inplace=True)
        
#         break
# since more than 20% of the values in normalized-losses is missing i.e. ?-mark
# Out:
# normalized-losses ?    41
# Name: normalized-losses, dtype: int64 ?    0.2
# Name: normalized-losses, dtype: float64
# num-of-doors ?    2
# Name: num-of-doors, dtype: int64 ?    0.009756
# Name: num-of-doors, dtype: float64
# bore ?    4
# Name: bore, dtype: int64 ?    0.019512
# Name: bore, dtype: float64
# stroke ?    4
# Name: stroke, dtype: int64 ?    0.019512
# Name: stroke, dtype: float64
# horsepower ?    2
# Name: horsepower, dtype: int64 ?    0.009756
# Name: horsepower, dtype: float64
# peak-rpm ?    2
# Name: peak-rpm, dtype: int64 ?    0.009756
# Name: peak-rpm, dtype: float64
# price ?    4
# Name: price, dtype: int64 ?    0.019512
# Name: price, dtype: float64

# %%
# mean or median - ?

# %%
data['normalized-losses']=data['normalized-losses'].replace('?',0)
data['normalized-losses'] = data['normalized-losses'].astype(float)
data['normalized-losses']=data['normalized-losses'].replace(0,np.mean(data['normalized-losses']))

data['bore']=data['bore'].replace('?',0)
data['bore'] = data['bore'].astype(float)
data['bore']=data['bore'].replace(0,np.mean(data['bore']))

data['stroke']=data['stroke'].replace('?',0)
data['stroke'] = data['stroke'].astype(float)
data['stroke']=data['stroke'].replace(0,np.mean(data['stroke']))

data['horsepower']=data['horsepower'].replace('?',0)
data['horsepower'] = data['horsepower'].astype(float)
data['horsepower']=data['horsepower'].replace(0,np.mean(data['horsepower']))

data['peak-rpm']=data['peak-rpm'].replace('?',0)
data['peak-rpm'] = data['peak-rpm'].astype(float)
data['peak-rpm']=data['peak-rpm'].replace(0,np.mean(data['peak-rpm']))

data['price']=data['price'].replace('?',0)
data['price'] = data['price'].astype(float)
data['price']=data['price'].replace(0,np.mean(data['price']))

# %%
# from sklearn.impute import SimpleImputer
# imputer = SimpleImputer(missing_values='?', strategy='mean')
# imputer = imputer.fit(data)
# data = imputer.transform(data)
# data.head()

# %%
# Handling missing values
# 1. Removing those values from dataset. 
# 2. Create a seperate models for handling missing values for each features in the dataset. (Time consuming)
# 3. Statistical methods - mean, median and mode.
# Dropping the particular feature itself.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    float64
#  19  stroke             205 non-null    float64
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    float64
#  22  peak-rpm           205 non-null    float64
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    float64
# dtypes: float64(11), int64(5), object(10)
# memory usage: 41.8+ KB

# %% [markdown]
# # Outlier detection and handling

# %% [markdown]
# 1. Data points that fall outside 1.5 times of an interquatile range above of the 3rd quantile and below the 1st quantile range
# 2. Data points that fall outside of 3 std. we can use z score and if that z score falls outside of 2 standard deviation

# %%
# Using Z-score
def find_outlier(data,col):
    mean = np.mean(data[col])
    threshold = 3
    std = np.std(data[col])
    outliers = []
    for i in data[col].values.tolist():
        zscore = (i-mean)/std
        if np.abs(zscore) > threshold:
            outliers.append(i)
    return outliers

# %%
# data['price'] = data['price'].astype(float)
# print(find_outlier(data,'price'))
print(find_outlier(data,'normalized-losses'))
print(find_outlier(data,'highway-mpg'))
print(find_outlier(data,'city-mpg'))
print(find_outlier(data,'compression-ratio'))
print(find_outlier(data,'engine-size'))

# data = data[~data.price.isin(find_outlier(data,'price'))]
data = data[~data['normalized-losses'].isin(find_outlier(data,'normalized-losses'))]
data = data[~data['wheel-base'].isin(find_outlier(data,'wheel-base'))]
data = data[~data['highway-mpg'].isin(find_outlier(data,'highway-mpg'))]
data = data[~data['city-mpg'].isin(find_outlier(data,'city-mpg'))]
data = data[~data['compression-ratio'].isin(find_outlier(data,'compression-ratio'))]
data = data[~data['engine-size'].isin(find_outlier(data,'engine-size'))]
print(data.shape)
# Out:
# [231.0, 256.0]
# [53, 54]
# [47, 49, 45]
# [22.7, 22.5, 22.5, 22.5, 23.0, 23.0, 23.0, 23.0, 23.0]
# [258, 258, 326, 308, 304]
# (185, 26)

# %% [markdown]
# # Anomaly detection and handling

# %%
# def estimateGaussian(X):
#     m = X.shape[0]
#     #compute mean of X
#     sum_ = np.sum(X,axis=0)
#     mu = (sum_/m)
#     # compute variance of X
#     var = np.var(X,axis=0)
#     return mu,var

# def multivariateGaussian(X, mu, sigma):
# #     k = len(mu)
#     sigma=np.diag(sigma)
#     X = X - mu.T
#     p = 1/((2*np.pi)**(k/2)*(np.linalg.det(sigma)**0.5))* np.exp(-0.5* np.sum(X @ np.linalg.pinv(sigma) * X,axis=1))
#     return p
# mu, sigma = estimateGaussian(data['price'])
# print(mu, sigma)
# p = multivariateGaussian(data['price'], mu, sigma)

# %%
# Create Artificial Data with Multivariate Outliers
# d1 = np.random.multivariate_normal(mean = np.array([-.5, 0]),cov = np.array([[1, 0], [0, 1]]), size = 100)
# d2 = np.random.multivariate_normal(mean = np.array([15, 10]),cov = np.array([[1, 0.3], [.3, 1]]), size = 100)
# outliers = np.array([[0, 10],[0, 9.5]])
# d = pd.DataFrame(np.concatenate([d1, d2, outliers], axis = 0), columns = ['Var 1', 'Var 2'])
################### Train Isolation Forest #################
from sklearn import ensemble
anomaly_data = data[['normalized-losses','wheel-base','highway-mpg','city-mpg','compression-ratio','engine-size','price']]
model  =  ensemble.IsolationForest(n_estimators=50, max_samples=500, contamination=.01, max_features=2, 
                         bootstrap=False, n_jobs=1, random_state=1, verbose=0, warm_start=False).fit(anomaly_data)
# Get Anomaly Scores and Predictions
anomaly_score = model.decision_function(anomaly_data)
predictions = model.predict(anomaly_data)
######### Visualize Anomaly scores and Anomaly Status ########
plt.figure(figsize = (10, 6), dpi = 150)
s = plt.scatter(data['normalized-losses'], data['price'], c = anomaly_score, cmap = 'coolwarm')
plt.colorbar(s, label = 'More Negative = More Anomalous')
plt.xlabel('normalized-losses', fontsize = 16)
plt.ylabel('price', fontsize = 16)
plt.grid()
# To Plot Predictions
plt.figure(figsize = (10, 6), dpi = 150)
s = plt.scatter(data['wheel-base'], data['price'], c = predictions, cmap = 'coolwarm')
plt.colorbar(s, label = 'More Negative = More Anomalous')
plt.xlabel('wheel-base', fontsize = 16)
plt.ylabel('price', fontsize = 16)
plt.grid()
# plt.title('Contamination = 0.01', weight = 'bold')
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\ensemble\_iforest.py:289: UserWarning: max_samples (500) is greater than the total number of samples (185). max_samples will be set to n_samples for estimation.
#   warn(
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Handling Higly Correlated variables

# %%
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  185.000000         185.000000  185.000000  185.000000  185.000000
# mean     0.848649         117.061622   98.497838  173.738378   65.824324
# std      1.259231          31.483824    5.626895   11.678440    2.024712
# min     -2.000000          65.000000   86.600000  144.600000   61.800000
# 25%      0.000000          97.600000   94.500000  166.800000   64.000000
# 50%      1.000000         104.000000   96.500000  173.200000   65.400000
# 75%      2.000000         142.000000  101.200000  181.700000   66.500000
# max      3.000000         197.000000  115.600000  202.600000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  185.000000   185.000000   185.000000  185.000000  185.000000
# mean    53.730811  2534.070270   123.767568    3.334211    3.235933
# std      2.462120   478.374763    32.932161    0.268633    0.309561
# min     48.800000  1819.000000    70.000000    2.540000    2.070000
# 25%     52.000000  2140.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.230000
# 75%     55.500000  2921.000000   141.000000    3.590000    3.410000
# max     59.800000  3770.000000   234.000000    3.940000    3.900000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         185.000000  185.000000   185.000000  185.000000   185.000000
# mean            9.458486  104.380962  5167.301252   24.735135    30.324324
# std             2.745219   36.361284   473.758468    5.573629     5.780656
# min             7.000000   60.000000  4150.000000   15.000000    18.000000
# 25%             8.600000   73.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   97.000000  5200.000000   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   29.000000    34.000000
# max            21.500000  288.000000  6600.000000   38.000000    47.000000
#
#               price
# count    185.000000
# mean   12713.836309
# std     6978.578633
# min     5118.000000
# 25%     7775.000000
# 50%    10345.000000
# 75%    15985.000000
# max    41315.000000

# %%
# anomaly detection and handling using gaussion mixture models
data.corr().abs()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.414863    0.538496  0.337275
# normalized-losses   0.414863           1.000000    0.083387  0.042176
# wheel-base          0.538496           0.083387    1.000000  0.856974
# length              0.337275           0.042176    0.856974  1.000000
# width               0.197856           0.032509    0.770254  0.815386
# height              0.578887           0.324367    0.649534  0.545816
# curb-weight         0.188490           0.001411    0.741427  0.862278
# engine-size         0.052096           0.009429    0.486150  0.654125
# bore                0.112847           0.109241    0.460177  0.589997
# stroke              0.005038           0.013477    0.099793  0.086273
# compression-ratio   0.197846           0.001709    0.424019  0.295729
# horsepower          0.131595           0.069616    0.269238  0.503050
# peak-rpm            0.259949           0.210792    0.353095  0.289905
# city-mpg            0.107183           0.116184    0.422207  0.661823
# highway-mpg         0.031297           0.074634    0.507548  0.700559
# price               0.027181           0.028508    0.488723  0.631817
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling          0.197856  0.578887     0.188490     0.052096  0.112847
# normalized-losses  0.032509  0.324367     0.001411     0.009429  0.109241
# wheel-base         0.770254  0.649534     0.741427     0.486150  0.460177
# length             0.815386  0.545816     0.862278     0.654125  0.589997
# width              1.000000  0.320119     0.847107     0.700261  0.538669
# height             0.320119  1.000000     0.373583     0.149071  0.208503
# curb-weight        0.847107  0.373583     1.000000     0.837974  0.640881
# engine-size        0.700261  0.149071     0.837974     1.000000  0.599996
# bore               0.538669  0.208503     0.640881     0.599996  1.000000
# stroke             0.162379  0.074658     0.123212     0.204395  0.078869
# compression-ratio  0.334816  0.298795     0.353544     0.226932  0.214183
# horsepower         0.599082  0.062635     0.713896     0.799840  0.544594
# peak-rpm           0.200654  0.322079     0.270200     0.249587  0.301686
# city-mpg           0.642065  0.099718     0.773148     0.671899  0.539904
# highway-mpg        0.676487  0.175747     0.819046     0.680286  0.548794
# price              0.672183  0.179286     0.780037     0.816470  0.506421
#
#                      stroke  compression-ratio  horsepower  peak-rpm  \
# symboling          0.005038           0.197846    0.131595  0.259949
# normalized-losses  0.013477           0.001709    0.069616  0.210792
# wheel-base         0.099793           0.424019    0.269238  0.353095
# length             0.086273           0.295729    0.503050  0.289905
# width              0.162379           0.334816    0.599082  0.200654
# height             0.074658           0.298795    0.062635  0.322079
# curb-weight        0.123212           0.353544    0.713896  0.270200
# engine-size        0.204395           0.226932    0.799840  0.249587
# bore               0.078869           0.214183    0.544594  0.301686
# stroke             1.000000           0.181921    0.103483  0.016825
# compression-ratio  0.181921           1.000000    0.047377  0.392755
# horsepower         0.103483           0.047377    1.000000  0.137915
# peak-rpm           0.016825           0.392755    0.137915  1.000000
# city-mpg           0.055886           0.098761    0.798689  0.059490
# highway-mpg        0.052570           0.003487    0.747592  0.003002
# price              0.021669           0.234675    0.730305  0.046279
#
#                    city-mpg  highway-mpg     price
# symboling          0.107183     0.031297  0.027181
# normalized-losses  0.116184     0.074634  0.028508
# wheel-base         0.422207     0.507548  0.488723
# length             0.661823     0.700559  0.631817
# width              0.642065     0.676487  0.672183
# height             0.099718     0.175747  0.179286
# curb-weight        0.773148     0.819046  0.780037
# engine-size        0.671899     0.680286  0.816470
# bore               0.539904     0.548794  0.506421
# stroke             0.055886     0.052570  0.021669
# compression-ratio  0.098761     0.003487  0.234675
# horsepower         0.798689     0.747592  0.730305
# peak-rpm           0.059490     0.003002  0.046279
# city-mpg           1.000000     0.963996  0.686869
# highway-mpg        0.963996     1.000000  0.696997
# price              0.686869     0.696997  1.000000

# %%
data['price']=data['price'].astype(float)
data['normalized-losses']=data['normalized-losses'].astype(float)

# %%
plt.figure(figsize=(20,5))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
# Univariate Analysis of discrete variables
plt.figure(figsize=(20,5))
plt.hist(data['make'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.hist(data['fuel-type'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.hist(data['aspiration'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.hist(data['drive-wheels'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.hist(data['body-style'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.hist(data['peak-rpm'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.scatter(data['peak-rpm'],data['price'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.scatter(data['body-style'],data['price'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.scatter(data['drive-wheels'],data['price'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.scatter(data['engine-size'],data['price'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.scatter(data['horsepower'],data['price'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.scatter(data['length'],data['price'])
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.scatter(data['engine-location'],data['price'])
plt.show()

# %% [markdown]
# # Feature Selection and Feature Engineering

# %% [markdown]
# Feature Selection by Checking for any constant columns from all the continous variables list

# %%
from sklearn.feature_selection import VarianceThreshold 
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(anomaly_data)
var_thres.get_support()
constant_columns = [column for column in anomaly_data.columns
                    if column not in anomaly_data.columns[var_thres.get_support()]]
print(len(constant_columns))
# Out:
# 0

# %% [markdown]
# Feature Selection using correlation matrix

# %%
def select_features_using_correlation(corr_mat):
    corr_columns = set()
    for i in corr_mat.columns:
        for j in corr_mat.columns:
            if i!=j and abs(corr_mat.loc[i,j]) > 0.7:
                corr_columns.add(i)
    return corr_columns
corr_columns = select_features_using_correlation(data.corr())
corr_columns.remove('price')
print(corr_columns)
# Out:
# {'curb-weight', 'width', 'length', 'wheel-base', 'highway-mpg', 'city-mpg', 'engine-size', 'horsepower'}

# %%
print(f"Before: {data.shape}")
data = data.drop(corr_columns,axis = 1)
print(f"After: {data.shape}")
# Out:
# Before: (185, 26)
# After: (185, 18)

# %% [markdown]
# # Label Encoding for Categorical features

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
# 'make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','fuel-system'
encoder.fit(data['make'])
data['make'] = encoder.transform(data['make'])
# encoder.classes_

encoder.fit(data['fuel-type'])
data['fuel-type'] = encoder.transform(data['fuel-type'])

encoder.fit(data['aspiration'])
data['aspiration'] = encoder.transform(data['aspiration'])

encoder.fit(data['num-of-doors'])
data['num-of-doors'] = encoder.transform(data['num-of-doors'])

encoder.fit(data['body-style'])
data['body-style'] = encoder.transform(data['body-style'])

encoder.fit(data['drive-wheels'])
data['drive-wheels'] = encoder.transform(data['drive-wheels'])

encoder.fit(data['fuel-system'])
data['fuel-system'] = encoder.transform(data['fuel-system'])

encoder.fit(data['engine-location'])
data['engine-location'] = encoder.transform(data['engine-location'])

encoder.fit(data['engine-type'])
data['engine-type'] = encoder.transform(data['engine-type'])

encoder.fit(data['num-of-cylinders'])
data['num-of-cylinders'] = encoder.transform(data['num-of-cylinders'])

# %% [markdown]
# # Train and Test data

# %%
from sklearn.model_selection import train_test_split
X = data.drop('price',axis = 1)
X_train,X_test,Y_train,Y_test = train_test_split(X,data['price'],test_size = 0.2)
X_train.shape,X_test.shape
# Out:
# ((148, 17), (37, 17))

# %% [markdown]
# # Model Training

# %%
X_train.head()
# Out:
#      symboling  normalized-losses  make  fuel-type  aspiration  num-of-doors  \
# 130          0               97.6    15          1           0             1
# 19           1               98.0     3          1           0             2
# 82           3               97.6    10          1           1             2
# 200         -1               95.0    20          1           0             1
# 167          2              134.0    18          1           0             2
#
#      body-style  drive-wheels  engine-location  height  engine-type  \
# 130           4             1                0    55.2            3
# 19            2             1                0    52.0            3
# 82            2             1                0    50.2            3
# 200           3             2                0    55.5            3
# 167           1             2                0    52.0            3
#
#      num-of-cylinders  fuel-system  bore  stroke  compression-ratio  \
# 130                 2            5  3.46    3.90                8.7
# 19                  2            1  3.03    3.11                9.6
# 82                  2            6  3.58    3.86                7.0
# 200                 2            5  3.78    3.15                9.5
# 167                 2            5  3.62    3.50                9.3
#
#         peak-rpm
# 130  5075.365854
# 19   5400.000000
# 82   5000.000000
# 200  5400.000000
# 167  4800.000000

# %%
from numpy import asarray
from pandas import read_csv
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

model = XGBRegressor(n_estimators = 1000,max_depth = 10)
# fit model
model.fit(X_train, Y_train)
# define new data
# make a prediction
Y_pred_train = model.predict(X_train)
Y_pred_test = model.predict(X_test)
train_rmse_score = mean_squared_error(Y_pred_train,Y_train,squared=False)
test_rmse_score = mean_squared_error(Y_pred_test,Y_test,squared=False)
# summarize prediction
print(f"train_rmse_score: {train_rmse_score}")
print(f"test_rmse_score: {test_rmse_score}")
# Out:
# train_rmse_score: 424.38898048920584
# test_rmse_score: 3685.949033605491

# %%
Y_pred_train
# Out:
# array([ 9294.499 ,  6295.1553, 12634.521 , 16857.834 ,  9826.595 ,
#         7053.529 , 18150.459 ,  8010.9067,  7677.409 , 11258.783 ,
#        41308.95  ,  6575.3545, 14675.665 ,  9826.595 , 14997.556 ,
#        22614.986 ,  7954.965 , 14675.665 , 20969.777 ,  9722.773 ,
#        12949.763 , 15998.147 ,  6028.543 ,  9722.773 ,  9569.25  ,
#         7149.7695,  5844.1084,  7690.636 , 15754.067 ,  7771.4277,
#         7902.5034, 12965.999 , 14964.543 ,  5398.053 ,  5788.8506,
#         6838.8306,  7784.408 ,  7296.13  , 12948.374 ,  5117.899 ,
#        14265.979 ,  8206.048 , 35055.477 ,  6855.4297, 12949.499 ,
#         6484.7803,  9234.853 , 18918.592 , 12294.826 ,  8495.459 ,
#         6365.11  ,  9991.648 ,  9961.138 , 18419.18  , 24560.271 ,
#         6028.543 ,  7603.9053,  7784.408 , 14461.591 ,  9958.963 ,
#         6028.543 , 33277.297 ,  7973.3457, 15690.029 ,  7149.7695,
#         7134.618 , 14997.556 ,  9276.92  ,  6694.5283,  7467.252 ,
#        15250.574 ,  6484.7803,  6229.2476,  7677.409 , 11046.004 ,
#         9390.53  , 31598.408 ,  9514.528 , 13301.787 , 13837.116 ,
#         8250.255 ,  8979.607 ,  8923.962 , 12294.826 , 10195.682 ,
#         8233.658 ,  8496.757 , 18621.89  , 11540.51  , 11202.116 ,
#         8496.757 , 16500.314 , 11851.907 , 19046.47  , 14461.591 ,
#        16016.391 , 18149.672 ,  8773.314 , 33277.297 , 16503.012 ,
#        23874.479 , 12950.504 ,  8065.395 , 15576.53  , 21484.646 ,
#        25556.771 , 16924.975 , 22017.355 , 16016.391 , 17711.184 ,
#         6486.5225, 12766.771 ,  7789.339 , 28245.996 , 17668.875 ,
#         9924.759 , 14265.979 ,  5579.265 ,  5844.1084,  9282.114 ,
#        12945.961 ,  9538.14  ,  7589.6455,  6484.7803,  7294.578 ,
#        10344.817 , 14964.543 ,  5577.6436,  6701.2725,  6228.66  ,
#         9924.759 , 13499.167 ,  5788.8506, 12277.496 ,  6529.8745,
#        15467.312 , 15467.312 ,  7386.204 , 30764.924 , 17201.941 ,
#        11692.76  , 16016.391 ,  7589.6455,  9569.25  ,  9390.53  ,
#        13837.116 , 11593.633 ,  9985.282 ], dtype=float32)

# %%
# k - fold cross validation
# rmse, r2, evaluation metrics, best metrics for regression
from sklearn.model_selection import cross_validate, KFold
scores = cross_validate(model,X_train,Y_train,scoring=('neg_mean_squared_error','r2'))
scores
# Out:
# {'fit_time': array([1.42319083, 2.37763977, 1.65257859, 2.33475447, 2.67184997]),
#  'score_time': array([0.00897574, 0.01795173, 0.00997257, 0.0209446 , 0.0089767 ]),
#  'test_neg_mean_squared_error': array([ -8951885.31038215, -16908817.22472499,  -2628651.69739419,
#         -10415741.80217084, -23207624.28383779]),
#  'test_r2': array([0.58691571, 0.73173952, 0.93124598, 0.65205047, 0.59028173])}

# %%
from sklearn.model_selection import KFold
kfold_cv = KFold(shuffle=True,random_state=42)

# %%
X.shape,data['price'].shape
# Out:
# ((185, 17), (185,))

# %%
for i,(x,y) in enumerate(kfold_cv.split(data)):
    X_train,X_test,Y_train,Y_test = X[X.index.isin(x)],X[X.index.isin(y)],data['price'][data.index.isin(x)],data['price'][data.index.isin(y)]
    print(X_train.shape,X_test.shape)
    model.fit(X_train, Y_train)
    # define new data
    # make a prediction
    Y_pred_train = model.predict(X_train)
    Y_pred_test = model.predict(X_test)
    train_rmse_score = mean_squared_error(Y_pred_train,Y_train,squared=False)
    test_rmse_score = mean_squared_error(Y_pred_test,Y_test,squared=False)
    # summarize prediction
    print(f"k-fold: {i}")
    print(f"train_rmse_score: {train_rmse_score}")
    print(f"test_rmse_score: {test_rmse_score}")
# Out:
# (135, 17) (34, 17)
# k-fold: 0
# train_rmse_score: 581.635713923538
# test_rmse_score: 2592.985351600199
# (135, 17) (34, 17)
# k-fold: 1
# train_rmse_score: 418.7040190394369
# test_rmse_score: 4470.555548250706
# (133, 17) (36, 17)
# k-fold: 2
# train_rmse_score: 641.9699104479274
# test_rmse_score: 2384.695257238887
# (135, 17) (34, 17)
# k-fold: 3
# train_rmse_score: 597.9421593530149
# test_rmse_score: 5072.36832650151
# (138, 17) (31, 17)
# k-fold: 4
# train_rmse_score: 495.1621532149842
# test_rmse_score: 2919.4680238009

# %% [markdown]
# # Model Building: Using Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
estimators = [100,200,500,750,1000]
for est in estimators: 
    model = RandomForestRegressor(n_estimators = est,criterion = 'squared_error')
    for i,(x,y) in enumerate(kfold_cv.split(data)):
        X_train,X_test,Y_train,Y_test = X[X.index.isin(x)],X[X.index.isin(y)],data['price'][data.index.isin(x)],data['price'][data.index.isin(y)]
        print(X_train.shape,X_test.shape)
        model.fit(X_train, Y_train)
        # define new data
        # make a prediction
        Y_pred_train = model.predict(X_train)
        Y_pred_test = model.predict(X_test)
        train_rmse_score = mean_squared_error(Y_pred_train,Y_train,squared=False)
        test_rmse_score = mean_squared_error(Y_pred_test,Y_test,squared=False)
        # summarize prediction
        print(f"k-fold: {i} n_estimator: {est}")
        print(f"train_rmse_score: {train_rmse_score}")
        print(f"test_rmse_score: {test_rmse_score}")
# Out:
# (135, 17) (34, 17)
# k-fold: 0 n_estimator: 100
# train_rmse_score: 1276.6516119261214
# test_rmse_score: 3588.506138842278
# (135, 17) (34, 17)
# k-fold: 1 n_estimator: 100
# train_rmse_score: 1366.6114036062859
# test_rmse_score: 2441.7698835922392
# (133, 17) (36, 17)
# k-fold: 2 n_estimator: 100
# train_rmse_score: 1524.335524943402
# test_rmse_score: 2465.9666250955393
# (135, 17) (34, 17)
# k-fold: 3 n_estimator: 100
# train_rmse_score: 1330.3179073450683
# test_rmse_score: 4441.754383431421
# (138, 17) (31, 17)
# k-fold: 4 n_estimator: 100
# train_rmse_score: 1302.3468173938413
# test_rmse_score: 2965.130401695904
# (135, 17) (34, 17)
# k-fold: 0 n_estimator: 200
# train_rmse_score: 1432.1770131295318
# test_rmse_score: 3742.1944604023106
# (135, 17) (34, 17)
# k-fold: 1 n_estimator: 200
# train_rmse_score: 1361.9238550724447
# test_rmse_score: 2192.3713306268
# (133, 17) (36, 17)
# k-fold: 2 n_estimator: 200
# train_rmse_score: 1414.6633872423429
# test_rmse_score: 2532.8195698625846
# (135, 17) (34, 17)
# k-fold: 3 n_estimator: 200
# train_rmse_score: 1434.495046359819
# test_rmse_score: 4074.362859234552
# (138, 17) (31, 17)
# k-fold: 4 n_estimator: 200
# train_rmse_score: 1238.1146878884501
# test_rmse_score: 2849.8896884691076
# (135, 17) (34, 17)
# k-fold: 0 n_estimator: 500
# train_rmse_score: 1342.6373457074883
# test_rmse_score: 3552.3126618637184
# (135, 17) (34, 17)
# k-fold: 1 n_estimator: 500
# train_rmse_score: 1358.1177919898355
# test_rmse_score: 2318.124606926355
# (133, 17) (36, 17)
# k-fold: 2 n_estimator: 500
# train_rmse_score: 1359.3668841057665
# test_rmse_score: 2427.1605124495195
# (135, 17) (34, 17)
# k-fold: 3 n_estimator: 500
# train_rmse_score: 1392.7120246152983
# test_rmse_score: 4216.271218404549
# (138, 17) (31, 17)
# k-fold: 4 n_estimator: 500
# train_rmse_score: 1255.9412867386425
# test_rmse_score: 2972.7934506301212
# (135, 17) (34, 17)
# k-fold: 0 n_estimator: 750
# train_rmse_score: 1386.5215176478891
# test_rmse_score: 3656.2000556461066
# (135, 17) (34, 17)
# k-fold: 1 n_estimator: 750
# train_rmse_score: 1367.6865632339648
# test_rmse_score: 2245.2220250150845
# (133, 17) (36, 17)
# k-fold: 2 n_estimator: 750
# train_rmse_score: 1378.2136693304792
# test_rmse_score: 2464.9808919514994
# (135, 17) (34, 17)
# k-fold: 3 n_estimator: 750
# train_rmse_score: 1357.727030325236
# test_rmse_score: 4146.167688484416
# (138, 17) (31, 17)
# k-fold: 4 n_estimator: 750
# train_rmse_score: 1230.9814103175083
# test_rmse_score: 2948.9944878881884
# (135, 17) (34, 17)
# k-fold: 0 n_estimator: 1000
# train_rmse_score: 1374.445543376128
# test_rmse_score: 3624.467270030949
# (135, 17) (34, 17)
# k-fold: 1 n_estimator: 1000
# train_rmse_score: 1389.4211601147667
# test_rmse_score: 2346.242525901241
# (133, 17) (36, 17)
# k-fold: 2 n_estimator: 1000
# train_rmse_score: 1371.4845899183265
# test_rmse_score: 2443.3423847165436
# (135, 17) (34, 17)
# k-fold: 3 n_estimator: 1000
# train_rmse_score: 1414.8639134756509
# test_rmse_score: 4299.738170757501
# (138, 17) (31, 17)
# k-fold: 4 n_estimator: 1000
# train_rmse_score: 1214.582755510126
# test_rmse_score: 2981.651009795859

# %%
import cv2
img = cv2.imread('D:\\Cloud4c\\attachments\\sem 1.jpg')
img.shape
# Out:
# (2742, 1835, 3)

# %%
import os
from tqdm.notebook import tqdm
def compressMe(file, verbose = False):

    print(file)
    files=os.listdir(file)
    err=0
    for i in tqdm(range(len(files))):
        if 'JPG' in files[i] or 'jpg' in files[i]:
            files[i]=file+'\\'+files[i]
            try:
                img = cv2.imread(files[i])
            except:
                print(files[i])
                err=err+1
                continue
            
            img = cv2.resize(img,(0,0),fx = 0.6,fy=0.6)
            cv2.imwrite(files[i], img,  [cv2.IMWRITE_PNG_COMPRESSION, 9])
    return

# Define a main function
def main():

    cwd = "D:\\Cloud4c\\attachments\\"
    formats = ('.jpg', '.jpeg')

    verbose = False
    compressMe(cwd, verbose)

    print("Done")
main()
# Out:
# D:\Cloud4c\attachments\
#   0%|          | 0/13 [00:00<?, ?it/s]
# Done
